# %%
# 데이터 가져오기

import pandas as pd

path = '../bicycle/bicycle.csv'
df = pd.read_csv(path, encoding="cp949")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   자전거번호    420 non-null    object
#  1   대여일시     420 non-null    object
#  2   대여소번호    420 non-null    int64
#  3   대여소명     420 non-null    object
#  4   대여거치대    396 non-null    float64
#  5   반납일시     420 non-null    object
#  6   반납대여소번호  420 non-null    int64
#  7   반납대여소명   420 non-null    object
#  8   반납거치대    409 non-null    float64
#  9   이용시간     405 non-null    float64
#  10  이용거리     404 non-null    float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 36.2+ KB

# %%
df
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0
# ...

# %%
df[(df['대여소번호']==646)]
# Out:
#         자전거번호             대여일시  대여소번호               대여소명  대여거치대  \
# 0   SPB-23220  2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1   SPB-16216  2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2   SPB-21097  2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3   SPB-22292  2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 5   SPB-18401  2019-11-06 8:52    646  장한평역 1번출구 (국민은행앞)    1.0
# 6   SPB-18350  2019-11-06 8:35    646  장한평역 1번출구 (국민은행앞)    1.0
# 8   SPB-20220  2019-11-11 8:35    646  장한평역 1번출구 (국민은행앞)    2.0
# 9   SPB-20102  2019-11-11 9:45    646  장한평역 1번출구 (국민은행앞)    8.0
# 10  SPB-10000  2019-11-12 8:35    646  장한평역 1번출구 (국민은행앞)    8.0
# 11  SPB-20145  2019-11-13 8:30    646  장한평역 1번출구 (국민은행앞)    9.0
# 12  SPB-19057  2019-11-13 8:55    646  장한평역 1번출구 (국민은행앞)    4.0
# 13  SPB-19645  2019-11-14 9:44    646  장한평역 1번출구 (국민은행앞)    NaN
# 14  SPB-21851  2019-11-14 9:33    646  장한평역 1번출구 (국민은행앞)   10.0
# 15  SPB-13973  2019-11-15 8:42    646  장한평역 1번출구 (국민은행앞)    1.0
# ...

# %%
df[df['대여소번호']==646].describe()
# Out:
#        대여소번호      대여거치대  반납대여소번호      반납거치대       이용시간         이용거리
# count   21.0  19.000000     21.0  20.000000  18.000000    19.000000
# mean   646.0   4.210526      3.0   4.000000  11.444444  1256.315789
# std      0.0   3.010702      0.0   2.513123   7.006066   129.323476
# min    646.0   1.000000      3.0   2.000000   5.000000  1060.000000
# 25%    646.0   1.500000      3.0   2.000000   7.000000  1135.000000
# 50%    646.0   4.000000      3.0   2.000000  10.000000  1310.000000
# 75%    646.0   6.000000      3.0   7.000000  11.750000  1360.000000
# max    646.0  10.000000      3.0   7.000000  30.000000  1420.000000

# %%
df[df['대여소번호']==646].isnull().sum()
# Out:
# 자전거번호      0
# 대여일시       0
# 대여소번호      0
# 대여소명       0
# 대여거치대      2
# 반납일시       0
# 반납대여소번호    0
# 반납대여소명     0
# 반납거치대      1
# 이용시간       3
# 이용거리       2
# dtype: int64

# %%
df[(df['대여소번호']==646)&df['이용시간'].isnull()]
# Out:
#         자전거번호             대여일시  대여소번호               대여소명  대여거치대  \
# 11  SPB-20145  2019-11-13 8:30  646.0  장한평역 1번출구 (국민은행앞)    9.0
# 16  SPB-22311  2019-11-18 8:32  646.0  장한평역 1번출구 (국민은행앞)    6.0
# 22  SPB-05857  2019-11-26 8:40  646.0  장한평역 1번출구 (국민은행앞)    6.0
#
#                반납일시  반납대여소번호 반납대여소명  반납거치대  이용시간    이용거리
# 11  2019-11-13 8:38      3.0   중랑센터    2.0   NaN  1060.0
# 16  2019-11-18 8:39      3.0   중랑센터    2.0   NaN  1350.0
# 22  2019-11-26 8:48      3.0   중랑센터    2.0   NaN  1380.0

# %%
df[(df['대여소번호']==646)&df['이용거리'].isnull()]
# Out:
# Empty DataFrame
# Columns: [자전거번호, 대여일시, 대여소번호, 대여소명, 대여거치대, 반납일시, 반납대여소번호, 반납대여소명, 반납거치대, 이용시간, 이용거리]
# Index: []

# %%
df[df['대여소번호']==646].mean()
# Out:
# 대여소번호       646.000000
# 대여거치대         4.411765
# 반납대여소번호       3.000000
# 반납거치대         3.666667
# 이용시간         11.562500
# 이용거리       1256.315789
# dtype: float64

# %%
df_test = df[df['대여소번호']==646]

# %%
df_test['이용시간'].isnull().sum()
# Out:
# 3

# %%
df_test
# Out:
#         자전거번호             대여일시     대여소번호               대여소명    대여거치대  \
# 0   SPB-23220  2019-11-01 8:48  646.0000  장한평역 1번출구 (국민은행앞)   3.0000
# 1   SPB-16216  2019-11-04 8:38  646.0000  장한평역 1번출구 (국민은행앞)   2.0000
# 3   SPB-22292  2019-11-05 8:34  646.0000  장한평역 1번출구 (국민은행앞)   1.0000
# 5   SPB-18401  2019-11-06 8:52  646.0000  장한평역 1번출구 (국민은행앞)   1.0000
# 6   SPB-18350  2019-11-06 8:35  646.0000  장한평역 1번출구 (국민은행앞)   1.0000
# 8   SPB-20220  2019-11-11 8:35  646.0000  장한평역 1번출구 (국민은행앞)   2.0000
# 9   SPB-20102  2019-11-11 9:45  646.0000  장한평역 1번출구 (국민은행앞)   8.0000
# 10  SPB-10000  2019-11-12 8:35  646.0000  장한평역 1번출구 (국민은행앞)   8.0000
# 11    11.5625          11.5625   11.5625            11.5625  11.5625
# 13  SPB-19645  2019-11-14 9:44  646.0000  장한평역 1번출구 (국민은행앞)      NaN
# 14  SPB-21851  2019-11-14 9:33  646.0000  장한평역 1번출구 (국민은행앞)  10.0000
# 15  SPB-13973  2019-11-15 8:42  646.0000  장한평역 1번출구 (국민은행앞)   1.0000
# 16    11.5625          11.5625   11.5625            11.5625  11.5625
# ...

# %%
df_test.mean()['이용시간']
# Out:
# 11.5625

# %%
df_test['이용시간'].isnull()
# Out:
# 0     False
# 1     False
# 3     False
# 5     False
# 6     False
# 8     False
# 9     False
# 10    False
# 11    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 21    False
# 22    False
# 24    False
# Name: 이용시간, dtype: bool

# %%
import numpy as np

# %%
df2 = df

# %%
df2.tail(20)
# Out:
#            자전거번호              대여일시        대여소번호          대여소명        대여거치대  \
# 400    SPB-15391  2019-11-14 17:14   113.000000  홍대입구역 2번출구 앞    22.000000
# 401    SPB-18517  2019-11-14 18:40   104.000000    합정역 1번출구 앞     1.000000
# 402    SPB-12442  2019-11-14 18:25   226.000000    샛강역 1번출구 앞    15.000000
# 403    SPB-11712  2019-11-14 19:19   104.000000    합정역 1번출구 앞     8.000000
# 404    SPB-23012  2019-11-14 19:53   267.000000     삼성화재 사옥 옆     2.000000
# 405    SPB-16711  2019-11-14 20:41   151.000000      망원1동주민센터     2.000000
# 406    SPB-23793  2019-11-14 21:43   826.000000    서울역 서부교차로2    18.000000
# 407    SPB-23154  2019-11-14 22:05   106.000000    합정역 7번출구 앞    10.000000
# 408    SPB-07283  2019-11-14 22:15   152.000000    마포구민체육센터 앞    17.000000
# 409  1256.315789       1256.315789  1256.315789   1256.315789  1256.315789
# 410    SPB-18614  2019-11-14 23:07   391.000000         정동길입구     5.000000
# ...

# %%
df3 = df2.replace({'이용거리':np.nan}, {'이용거리':'대표값'})

# %%
df3.head(20)
# Out:
#           자전거번호              대여일시        대여소번호               대여소명  \
# 0     SPB-23220   2019-11-01 8:48   646.000000  장한평역 1번출구 (국민은행앞)
# 1     SPB-16216   2019-11-04 8:38   646.000000  장한평역 1번출구 (국민은행앞)
# 2   1256.315789       1256.315789  1256.315789        1256.315789
# 3     SPB-22292   2019-11-05 8:34   646.000000  장한평역 1번출구 (국민은행앞)
# 4     SPB-07935  2019-11-05 12:29   512.000000        뚝섬역 1번 출구 옆
# 5     SPB-18401   2019-11-06 8:52   646.000000  장한평역 1번출구 (국민은행앞)
# 6     SPB-18350   2019-11-06 8:35   646.000000  장한평역 1번출구 (국민은행앞)
# 7     SPB-11557  2019-11-08 14:52     3.000000               중랑센터
# 8     SPB-20220   2019-11-11 8:35   646.000000  장한평역 1번출구 (국민은행앞)
# 9     SPB-20102   2019-11-11 9:45   646.000000  장한평역 1번출구 (국민은행앞)
# 10    SPB-10000   2019-11-12 8:35   646.000000  장한평역 1번출구 (국민은행앞)
# 11    SPB-20145   2019-11-13 8:30   646.000000  장한평역 1번출구 (국민은행앞)
# 12  1256.315789       1256.315789  1256.315789        1256.315789
# ...
