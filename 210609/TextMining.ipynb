# %%
#  Text mining 텍스트마이닝

# 1. 키워드 빈도수 분석
# 2. 키워드 연관 분석
# 3. 인터넷 웹페이지에 있는 이미지, 텍스트, 정보들을 스크랩해올꺼야 => 웹 크롤링

# %%
''' 

웹 크롤링

1. 개발자 모드로 변경 : F12 - 도구더보기 - 개발자도구

2. 3개의 라이브러리 설치

# !pip install requests beautifulsoup4 lxml

# !pip install cloudscraper                              -- 오류발생해서 이걸로 우회해야됨 기존에는 requests 로 불러왔었음

3. 


'''
# Out:
# ' \n\n웹 크롤링\n\n1. 개발자 모드로 변경 : F12 - 도구더보기 - 개발자도구\n\n2. 3개의 라이브러리 설치\n\n!pip install requests beautifulsoup4 lxml\n\n!pip install cloudscraper                              -- 오류발생해서 이걸로 우회해야됨 기존에는 requests 로 불러왔었음\n\n3. \n\n\n'

# %%
# !pip install requests beautifulsoup4 lxml
# Out:
# Requirement already satisfied: requests in c:\users\5-17\jupylab\lib\site-packages (2.25.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\5-17\jupylab\lib\site-packages (4.9.3)
# Requirement already satisfied: lxml in c:\users\5-17\jupylab\lib\site-packages (4.6.3)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\5-17\jupylab\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\5-17\jupylab\lib\site-packages (from requests) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\5-17\jupylab\lib\site-packages (from requests) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\5-17\jupylab\lib\site-packages (from requests) (4.0.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\5-17\jupylab\lib\site-packages (from beautifulsoup4) (2.2.1)

# %%
# !pip install cloudscraper
# Out:
# Requirement already satisfied: cloudscraper in c:\users\5-17\jupylab\lib\site-packages (1.2.58)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in c:\users\5-17\jupylab\lib\site-packages (from cloudscraper) (0.9.1)
# Requirement already satisfied: requests>=2.9.2 in c:\users\5-17\jupylab\lib\site-packages (from cloudscraper) (2.25.1)
# Requirement already satisfied: pyparsing>=2.4.7 in c:\users\5-17\jupylab\lib\site-packages (from cloudscraper) (2.4.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\5-17\jupylab\lib\site-packages (from requests>=2.9.2->cloudscraper) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\5-17\jupylab\lib\site-packages (from requests>=2.9.2->cloudscraper) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\5-17\jupylab\lib\site-packages (from requests>=2.9.2->cloudscraper) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\5-17\jupylab\lib\site-packages (from requests>=2.9.2->cloudscraper) (1.26.5)

# %%
# -*- coding: utf-8 -*-

# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
### 신규 코드 ###
import cloudscraper
scraper = cloudscraper.create_scraper()
req = scraper.get(source_url)
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# <ipython-input-41-ba2b66eb700c> in <module>
#       2 import cloudscraper
#       3 scraper = cloudscraper.create_scraper()
# ----> 4 req = scraper.get(source_url)
#
# NameError: name 'source_url' is not defined

# %%
import cloudscraper
from bs4 import BeautifulSoup                    # bs4 를 이용해서 HTML 의 정보들을 파싱(문법적 분석)
import re



# 크롤링할 사이트 주소를 정의합니다.
source_url = "https://namu.wiki/RecentChanges"



# 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
scraper = cloudscraper.create_scraper()
req = scraper.get(source_url)
html = req.content                                                #  html 에 전부 가져옴 구조 상관없이
soup = BeautifulSoup(html, 'lxml')                            #   막가져온 걸  뷰티풀 솝 방법으로 파싱(문법적 분석)
contents_table = soup.find(name="table")
table_body = contents_table.find(name="tbody")
table_rows = table_body.find_all(name="tr")

# %%
# a태그의 href 속성을 리스트로 추출하여, 크롤링 할 페이지 리스트를 생성합니다.
page_url_base = "https://namu.wiki"
page_urls = []
for index in range(0, len(table_rows)):
    first_td = table_rows[index].find_all('td')[0]
    td_url = first_td.find_all('a')
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get('href')
        if 'png' not in page_url:
            page_urls.append(page_url)

# 중복 url을 제거합니다.
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)
# Out:
# https://namu.wiki/w/%ED%8E%98%EC%9D%B4%ED%81%AC%20%EC%B5%9C%EC%A2%85%20%EB%B3%B4%EC%8A%A4%26%EC%A7%84%20%EC%B5%9C%EC%A2%85%20%EB%B3%B4%EC%8A%A4/%EC%BA%90%EB%A6%AD%ED%84%B0/%EA%B2%8C%EC%9E%84
# https://namu.wiki/w/%EC%84%9C%EC%9A%B8%20%ED%95%9C%EA%B5%AD%EC%B2%B4%EC%9C%A1%EB%8C%80%ED%95%99%EA%B5%90%20%ED%83%9C%ED%92%8D%20FC
# https://namu.wiki/w/Vision%20Strikers
# https://namu.wiki/w/%EC%87%BC%EC%9A%B0(%EC%98%81%EC%9B%90%ED%9A%8C%EA%B7%80:%20%EB%B8%94%EB%9E%99%EC%84%9C%EB%B0%94%EC%9D%B4%EB%B2%8C)
# https://namu.wiki/w/%EB%A1%9C%EC%8A%A4%EC%95%A4%EC%A0%A4%EB%A0%88%EC%8A%A4%20%EB%8B%A4%EC%A0%80%EC%8A%A4/2021%EB%85%84

# %%
# 페이지 내 텍스트 구조확인

req = scraper.get(page_urls[0])
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="article")
title = contents_table.find_all('h1')[0]
category = contents_table.find_all('ul')[0]
content_paragraphs = contents_table.find_all(name='div', attrs={'class':'wiki-paragraph'})
content_corpus_list = []

for paragraphs in content_paragraphs:
    content_corpus_list.append(paragraphs.text)
content_corpus = "".join(content_corpus_list)

print(title.text)
print('\n')
print(category.text)
print('\n')
print(content_corpus)
# Out:
# 페이크 최종 보스&진 최종 보스/캐릭터/게임
#
#
# 캐릭터 목록
#
#
#    이 문서를 편집한 기록이 있어야 편집 가능한 문서입니다.   상위 문서: 페이크 최종 보스&진 최종 보스/캐릭터1. 개요2. 기준3. 목록3.1. 숫자3.2. 영문3.3. 한글3.3.1. ㄱ3.3.2. ㄴ3.3.3. ㄷ3.3.4. ㄹ3.3.5. ㅁ3.3.6. ㅂ3.3.7. ㅅ3.3.8. ㅇ3.3.9. ㅈ3.3.10. ㅊ3.3.11. ㅋ3.3.12. ㅌ3.3.13. ㅍ3.3.14. ㅎ게임에 등장하는 페이크 최종 보스&진 최종 보스를 기록. 스포일러인 내용이 많으므로 주의하며, 스토리상 최종 보스는  기울임과 굵은 글씨로 표시 할 것.※ 조건 A 유형(배후의 진정한 적)은 ☆로 표시.※ 조건 B 유형((강제) 교체)은 ★로 표시.※ 조건 C-1 유형(특별한 중간 보스)은 ♧로 표시.※ 조건 C-2 유형(왕의 귀환)은 ○로 표시.※ 주인공인 경우는 ♤로 표시.※ 스토리별 페이크&진 최종 보스 중 마지막 스토리의 캐릭터는 (完)로 표시.[1]※ 미디어 믹스의 경우 원작과 페이크&진 최종 보스가 달라진 경우에만 따로 기술함.게임에서 처음 선보인 것은 패미컴판 위저드리. 격투 게임에서는 '특정 조건'을 만족시키지 못할 경우에도 이 용어를 사용하기도 한다. 그 효시는 스트리트 파이터 2의 베가[2]며, 실질적으로는 용호의 권 2의 기스 하워드라고 할 수 있다.이후 각종 격투 게임에서는 심심찮게 진 최종 보스가 등장하게 되었다. 이것은 격투 게임뿐만 아니라 다른 게임상에서도 위 사항과 같은데, 게임에서 등장하는 진 최종 보스는 다음과 같다.스토리 진행으로만 등장하는 페이크 최종 보스&진 최종 보스각종 영상물처럼 스토리 진행으로만 등장하는 유형.일정한 조건을 만족해야만 대면 할 수 있는 진 최종 보스의 유형실제로는 ♧에 해당되며 히든 보스와 비슷하지만, 페이크 최종 보스가 존재할 경우 배드 엔딩으로 끝나는 경우가 많으며, 배드 엔딩이 없는 페이크 최종 보스라도 결말이 어느 정도 찝찝한 경우가 많다. 이 케이스는 히든 보스와 종종 헷갈리는 경우가 많다.분기점을 잘못 선택 시에 등장하는 페이크 최종 보스이 패턴은 대개 RPG나 어드벤처, 일부 대전액션게임에서 자주 사용한다. 대전액션게임일 경우 노미스 클리어나 파이팅 레벨이 S랭크가 평균유무에 따라 분기점이 달라진다.(예: 아랑전설 3)페이크 최종 보스를 노 컨티뉴 및 노 미스 클리어 여부에 따라 등장하는 진 최종 보스대부분의 대전액션게임 장르에서 사용하는 패턴특정한 아이템을 확보 시에 등장하는 진 최종 보스레벨 업 만족 여부에 따라 등장하는 진 최종 보스1주차 최종 보스와 2주차 최종 보스도돈파치를 시작으로 케이브사의 슈팅게임들이 자주 사용하는 패턴난이도 설정에 따라 최종 보스가 다른 케이스일반적인 고전게임들이 주로 사용하는 유형. (예: 콘트라 시리즈, 록맨 X8)리듬게임 전반의 엑스트라 스테이지. (예: 응원단 시리즈)일본 RPG 계열에서 가장 유명한 건 역시 뭐니뭐니해도 드래곤 퀘스트 3의 바라모스 - 조마. 특히 이 당시에는 제작사의 언론 통제까지 있었기 때문에, 플레이어들의 충격이 몇 배나 컸다고 한다.상위 문서에서 든 두 예시들 중 전자인 마왕 - 대마왕이 바로 이 케이스를 예시로 든 것.※ 출현 조건이 있는 최종 보스는 밑에 서술.이 문서에 스포일러가 포함되어 있습니다.이 문서가 설명하는 작품이나 인물 등에 대한 줄거리, 결말, 반전 요소 등을 직·간접적으로 포함하고 있습니다.11eyes -죄와 벌과 속죄의 소녀-의 아바리티아 → 리제롯테 베르크마이스터19XX의 아우터리미츠 → F. 블래커(블랙 노이즈)★A Dance of Fire and Ice - Thanks For Playing My Game → One Forgotten NightCaligula -칼리굴라- - 쏜 → 뮤Chaos;Child - 사쿠마 와타루 → 와쿠이 슈이치[3]Cytus II - Ivy → Vanessa (1.0 ~ 3.0 버전까지)DmC: 데빌 메이 크라이의 문두스 → 버질[4]Enter the Gungeon - 하이 드래건 → 과거의 보스 (파일럿, 죄수, 해병, 사냥꾼) → 리치대면 조건은 여기에서 참조Fate 시리즈Fate/stay night Heavens Feel 루트의 마토 사쿠라 → 코토미네 키레이Fate/EXTRA CCC의 BB → 셋쇼인 키아라Fate/Grand Order1부의 솔로몬 → 마신왕 게티아절대마수전선 바빌로니아의 복합신성 고르곤 → 티아마트1.5부시산혈하무대 시모사노쿠니의 요술사 → 사사키 코지로2부영구동토제국 아나스타샤의 이반 뇌제 → 아나스타샤무간빙염세기 괴터데메룽의 수르트 → 스카사하=스카디 & 오르트린데인지통합진국 진의 시황제 → 우미인성간도시산맥 올림포스의 제우스 → 키르슈타리아 보다임 → 황금의 카이니스사이드 스토리서번트 서머 캠프!의 애비게일 윌리엄스 → 셋쇼인 키아라 → 서복GALZOO 아일랜드 - 이카남작 → 붉은 운명Hollow Knight - 공허의 기사 → 광휘Just Shapes & Beats - Final Boss → Annihilate & Till It's OverMonolith(게임) - 오버로드(5층 보스) → 더 머신(노멀모드 6층 보스) → 모노리스(하드모드 6층 보스)봉인의 문자를 4개 모은 상태에서 오버로드를 잡아야 6층에 진입 가능. 더 머신을 때려잡으면 하드 모드가 해금된다. [5]SdoricaSunset 편 - 쏜 → 시어도어 카를로스 → 랄프 라벤더Mirage 편 - 디비어스 루이스 마르코 → 심판의 마물 → 조라(용신교파)[6]Eclipse 편 - 미정Pixel Gun 3D/캠페인 - 드래곤 → 더 버그 → 큐빅 → ???가챠 월드 Final Boss → RNG Goddess Ellie[7]건 프론티어의 와일드리자드 군단의 거대전차 → 황금묘비황금묘비속에서 외관상 주인공 기체와 똑같은 전투기가 등장하며, 게임 진행 중에는 6발로 제한되어 있어 한 발이라도 진 최종 보스를 맞추어야 한다. 단, 진 최종 보스 중심으로 배리어가 형성되는데, 진행 중에는 컨티뉴가 없으며, 플레이어가 당할 시 배드 엔딩으로 끝난다.건그레이브 O.D의 돈 크레아레 코르시오네 → 가리노 크레아레 코르시오네건스타 히어로즈의 그레이 장군 → 골든 실버검은방 4의 강성중 → 허강민곡괭이 시리즈The King of Gockgang-E의 젊은이 → 신 & 악마[8]The Legend of Gockgang-E의 Dr. 파우스트 → 메피스토펠레스 → 킹 오브 곡괭이[9]고스트 오브 쓰시마 - 코툰 칸 → 시무라 공괭이갈매기 울 적에의 베아트리체(괭이갈매기 울 적에) → 베른카스텔 ★그라디우스 시리즈역대 그라디우스 시리즈의 최종 보스는 적 함선의 메인 컴퓨터인데, 최종 보스치고는 매우 허약하다.[10] 아케이드판 그라디우스 2부터 최종 스테이지에서는 부보스가 나타나는데, 플레이어가 파괴할 수 없어 한마디로 대책이 없으며, 즉, 본래의 최종 보스보다 더 강해서 사실상의 최종 보스로 취급한다.사라만다의 제로스 포스 → 메탈 슬레이브그라디우스 II의 크랩♧ → 고퍼고퍼의 야망 에피소드 II의 퀸즈 라이치♧ → 고퍼그라디우스 III의 새도우 기어(개량형 크랩)♧ → 박테리안그라디우스 IV의 크랩 mk2♧ → 고퍼사라만다 2의 켈베로스 → 둠파로디우스 시리즈의 여성무희♧[11] → 최종 보스오토메디우스의 고퍼자메&오딘 코어♧ → 최종 보스그라디우스 제네레이션의 회전벽 → 에레오스 브레인MSX판 그라디우스 2의 아바돈함 → 닥터 베놈[12]그로우랜서의 리샬, 게벨 → 벤젤극초호권의 파우엘 → 마헤스바라노컨티뉴로 파우엘을 쓰러트릴 것.기가 윙의 6면 보스 → 7면 보스날아라 슈퍼보드 -환상서유기-의 마황대제 → 옥황상제[13]☆네버윈터 나이츠의 발샤리스 → 메피스토텔레스[14]네오지오 배틀 컬리시엄 - 미즈치♧, 네오-디오♧, 진 사자왕♧(배드 엔딩) → 굿맨(진 엔딩)노 모어 히어로즈의 다크스타 → 진노부나가의 야망 - 도요토미 히데요시 → 도쿠가와 이에야스[15]니어:오토마타 의 이브 → 공자&노자 → 9S or A2 → 스탭롤닌자용검전 패미컴판2기의 흉마천제 아슈타 → 사귀왕 자퀴오3기의 짝퉁 류 하야부사 → 클랜시[16]다크 소울 시리즈다크 소울 2의 나샹드라 → 원죄의 탐 ...

# %%
# 웹 크롤링을 불러왔으면...
# 데이터 프레임을 만들 후 넣어주는 작업을 해야한다.

# %%
# 크롤링한 데이터를 데이터 프레임으로 만들기 위해 준비합니다.
columns = ['title', 'category', 'content_text']
df = pd.DataFrame(columns=columns)

# 각 페이지별 '제목', '카테고리', '본문' 정보를 데이터 프레임으로 만듭니다.
for page_url in page_urls:

    # 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
    req = scraper.get(page_url)
    html = req.content
    soup = BeautifulSoup(html, 'lxml')
    contents_table = soup.find(name="article")
    title = contents_table.find_all('h1')[0]
    
    # 카테고리 정보가 없는 경우를 확인합니다.
    if len(contents_table.find_all('ul')) > 0:
        category = contents_table.find_all('ul')[0]
    else:
        category = None
        
    content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
    content_corpus_list = []
    
    # 페이지 내 제목 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if title is not None:
        row_title = title.text.replace("\n", " ")
    else:
        row_title = ""
    
    # 페이지 내 본문 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if content_paragraphs is not None:
        for paragraphs in content_paragraphs:
            if paragraphs is not None:
                content_corpus_list.append(paragraphs.text.replace("\n", " "))
            else:
                content_corpus_list.append("")
    else:
        content_corpus_list.append("")
        
    # 페이지 내 카테고리정보에서 “분류”라는 단어와 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if category is not None:
        row_category = category.text.replace("\n", " ")
    else:
        row_category = ""
    
    # 모든 정보를 하나의 데이터 프레임에 저장합니다.
    row = [row_title, row_category, "".join(content_corpus_list)]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)

# %%
df.head(5)
# Out:
#                        title                               category  \
# 0  페이크 최종 보스&진 최종 보스/캐릭터/게임                                  캐릭터 목록
# 1          서울 한국체육대학교 태풍 FC   대한민국의 아마추어 축구단K6리그서울특별시 연고 구단1994년 창단
# 2           Vision Strikers                                  e스포츠 팀
# 3          쇼우(영원회귀: 블랙서바이벌)                        영원회귀: 블랙서바이벌/실험체
# 4          로스앤젤레스 다저스/2021년                        로스앤젤레스 다저스/2021년
#
#                                         content_text
# 0     이 문서를 편집한 기록이 있어야 편집 가능한 문서입니다.   상위 문서: 페이...
# 1   K6리그참가 구단 (2021)K6리그참가 구단 (2021) [ 펼치기 · 접기 ]...
# 2  Vision Strikers설립2020년 6월 8일소재지 대한민국모기업㈜이드림워크코...
# 3     은(는) 여기로 연결됩니다. 블랙서바이벌의 캐릭터 쇼우에 대한 내용은 쇼우(블...
# 4     상위 문서: 로스앤젤레스 다저스  로스앤젤레스 다저스 시즌별 성적2020년 시...

# %%
# 키워드 추출
# 텍스트 데이터 전처리

# %%
# 텍스트 정체 함수 : 한글 이외의 문자는 전부 제거합니다.
def text_cleaning(text):
    hangul = re.compile('[^ㄱ-ㅣ가-힣]+') # 한글의 정규표현식을 나타낸다
    result = hangul.sub('',text)
    return result

# %%
print(text_cleaning(df['content_text'][0]))
# Out:
# 이문서를편집한기록이있어야편집가능한문서입니다상위문서페이크최종보스진최종보스캐릭터개요기준목록숫자영문한글ㄱㄴㄷㄹㅁㅂㅅㅇㅈㅊㅋㅌㅍㅎ게임에등장하는페이크최종보스진최종보스를기록스포일러인내용이많으므로주의하며스토리상최종보스는기울임과굵은글씨로표시할것조건유형배후의진정한적은로표시조건유형강제교체은로표시조건유형특별한중간보스은로표시조건유형왕의귀환은로표시주인공인경우는로표시스토리별페이크진최종보스중마지막스토리의캐릭터는로표시미디어믹스의경우원작과페이크진최종보스가달라진경우에만따로기술함게임에서처음선보인것은패미컴판위저드리격투게임에서는특정조건을만족시키지못할경우에도이용어를사용하기도한다그효시는스트리트파이터의베가며실질적으로는용호의권의기스하워드라고할수있다이후각종격투게임에서는심심찮게진최종보스가등장하게되었다이것은격투게임뿐만아니라다른게임상에서도위사항과같은데게임에서등장하는진최종보스는다음과같다스토리진행으로만등장하는페이크최종보스진최종보스각종영상물처럼스토리진행으로만등장하는유형일정한조건을만족해야만대면할수있는진최종보스의유형실제로는에해당되며히든보스와비슷하지만페이크최종보스가존재할경우배드엔딩으로끝나는경우가많으며배드엔딩이없는페이크최종보스라도결말이어느정도찝찝한경우가많다이케이스는히든보스와종종헷갈리는경우가많다분기점을잘못선택시에등장하는페이크최종보스이패턴은대개나어드벤처일부대전액션게임에서자주사용한다대전액션게임일경우노미스클리어나파이팅레벨이랭크가평균유무에따라분기점이달라진다예아랑전설페이크최종보스를노컨티뉴및노미스클리어여부에따라등장하는진최종보스대부분의대전액션게임장르에서사용하는패턴특정한아이템을확보시에등장하는진최종보스레벨업만족여부에따라등장하는진최종보스주차최종보스와주차최종보스도돈파치를시작으로케이브사의슈팅게임들이자주사용하는패턴난이도설정에따라최종보스가다른케이스일반적인고전게임들이주로사용하는유형예콘트라시리즈록맨리듬게임전반의엑스트라스테이지예응원단시리즈일본계열에서가장유명한건역시뭐니뭐니해도드래곤퀘스트의바라모스조마특히이당시에는제작사의언론통제까지있었기때문에플레이어들의충격이몇배나컸다고한다상위문서에서든두예시들중전자인마왕대마왕이바로이케이스를예시로든것출현조건이있는최종보스는밑에서술이
�는없으며바로배드엔딩으로끝난다동굴이야기의닥터보로스부스터철의인연을소유해야보로스가있는숨겨진최종던전성역으로의입장이가능동방프로젝트동방환상향의잠옷바람유카평상복유카설정상출현조건노멀이상난이도에서노컨티뉴상태로면클리어이지난이도로하면면에서끝난다노말이상이라도면진입전에한번이라도컨티뉴를하면면에서배드엔딩이발생하며면에서죽을경우컨티뉴를할수없고역시배드엔딩동방홍마향의이자요이사쿠야레밀리아스칼렛출현조건노멀이상난이도에서면클리어이지난이 ...

# %%
# 각 피처마다 데이터 전처리를 적용한다.
df['title'] = df['title'].apply(lambda x: text_cleaning(x))
df['category'] = df['category'].apply(lambda x: text_cleaning(x))
df['content_text'] = df['content_text'].apply(lambda x: text_cleaning(x))
df.head(5)
# Out:
#                title                    category  \
# 0  페이크최종보스진최종보스캐릭터게임                       캐릭터목록
# 1        서울한국체육대학교태풍  대한민국의아마추어축구단리그서울특별시연고구단년창단
# 2                                           스포츠팀
# 3       쇼우영원회귀블랙서바이벌               영원회귀블랙서바이벌실험체
# 4         로스앤젤레스다저스년                  로스앤젤레스다저스년
#
#                                         content_text
# 0  이문서를편집한기록이있어야편집가능한문서입니다상위문서페이크최종보스진최종보스캐릭터개요기준...
# 1  리그참가구단리그참가구단펼치기접기강원조동해남호동해북평동해청솔속초조광정선태백중앙조원주무...
# 2  설립년월일소재지대한민국모기업이드림워크코리아양선일임현석종목발로란트워크래프트링크개요운영...
# 3  은는여기로연결됩니다블랙서바이벌의캐릭터쇼우에대한내용은쇼우블랙서바이벌문서를의번문단을의부...
# 4  상위문서로스앤젤레스다저스로스앤젤레스다저스시즌별성적년시즌년시즌년시즌로스앤젤레스다저스시...

# %%
# 말뭉치 만들기
# 각 피처마다 말뭉치를 생성합니다.

title_corpus = "".join(df['title'].tolist())
category_corpus = "".join(df['category'].tolist())
conten_corpus = "".join(df['content_text'].tolist())
print(title_corpus)
# Out:
# 페이크최종보스진최종보스캐릭터게임서울한국체육대학교태풍쇼우영원회귀블랙서바이벌로스앤젤레스다저스년친박역사치안히키코모리야루오가드물게등교했더니이세계행다이노스년월다케시타와타루자동전투근초고왕드라마아오야마요시노호미들위험한두명의일행대한성공회당신은약속의세계에태어난것같습니다영원회귀블랙서바이벌아이템장비옷양정아파일갤럭시전후면사진가상미션일람스토리미션흑막친황제의나라에어소프트건오하영리오영원회귀블랙서바이벌레알베티스발롬피에워드프레스루이즈프랑소와즈르블랑드라발리에르아스카료그리스와덴마크의마리나서번트세이버카르나산타너의밤이되어줄게미토안지생각모듬찌개네이션스리그시즌리그웬만해선그들을막을수없다기타에피소드한족동호형김학범년재보궐선거지역별결과부산광역시장기드온세븐나이츠신화각성황금사자기전국고교야구대회프리울리베네치아줄리아친유저스티스학원최종보스캐릭터게임교구남성피해불법촬영물대규모유포사건키아나카스라나작중행적이준석스텐기관단총파일조화객관환원이론파일로제타석이부시코타기계식시계메갈로복스아이돌월드컵카타르지역예선아시아차예선조카네시야시타라월드오브탱크블리츠가공전차김동선배구선수츠쿠다역도쿠시마에구치히사시애니메이터타나하시히로시민주주의좌위왕자림정주원분류미스터리
