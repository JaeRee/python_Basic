# %%
import pandas as pd

path = '../data/Seoul_school/Seoul_school.csv'

df = pd.read_csv(path, encoding='cp949')

df
# Out:
#         학교종류명 설립구분   표준학교코드                학교명  \
# 0     각종학교(중)   사립  7134155            선화예술중학교
# 1        초등학교   공립  7134150           서울숭신초등학교
# 2         중학교   공립  7134142              행당중학교
# 3         중학교   사립  7134141     한양대학교사범대학부속중학교
# 4         중학교   공립  7134140              자양중학교
# ...       ...  ...      ...                ...
# 3852     고등학교   국립  1371661           국립국악고등학교
# 3853     특수학교   국립  1342102             한국우진학교
# 3854     특수학교   국립  1342099              서울농학교
# 3855     특수학교   국립  1342098              서울맹학교
# 3856    공동실습소   공립        0  경기기계공업고등학교부설공동실습소
#
#                                     영문학교명           관할조직명   도로명우편번호  \
# 0               Sunhwa Arts Middle School  서울특별시성동광진교육지원청    4991.0
# 1       Seoul Soongshin Elementary School  서울특별시성동광진교육지원청    4702.0
# 2                 Haengdang Middle School  서울특별시성동광진교육지원청    4764.0
# 3        Hanyang University Middle School  서울특별시성동광진교육지원청    4761.0
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# 학교종류명
# 설립구분
# 표준학교코드
# 학교명
# 영문학교명
# 관할조직명
# 도로명우편번호
# 도로명주소
# 도로명상세주소
# 전화번호
# 홈페이지주소
# 팩스번호
# 남녀공학구분명
# 고등학교구분명
# 산업체특별학급존재여부
# 고등학교일반실업구분명
# 특수목적고등학교계열명
# 입시전후기구분명
# 주야구분명
# 설립일자
# 개교기념일
# 시도교육청코드
# 시도교육청명
# 소재지명
# 주야과정
# 계열명
# 학과명
# 적재일시

# %%
df_school = df[['학교명','도로명주소','도로명상세주소']]

# %%
df_school
# Out:
#                     학교명                  도로명주소             도로명상세주소
# 0               선화예술중학교     서울특별시 광진구 천호대로 664    / 선화예술중고등학교 (능동)
# 1              서울숭신초등학교      서울특별시 성동구 마장로 161             (하왕십리동)
# 2                 행당중학교     서울특별시 성동구 왕십리로 189         (행당동/행당중학교)
# 3        한양대학교사범대학부속중학교       서울특별시 성동구 마조로 42  (사근동/한양사대부속중?고등학교)
# 4                 자양중학교    서울특별시 광진구 뚝섬로41길 33       (자양동/서울자양중학교)
# ...                 ...                    ...                 ...
# 3852           국립국악고등학교    서울특별시 강남구 개포로22길 65   / (개포동/ 국립국악고등학교)
# 3853             한국우진학교  서울특별시 마포구 월드컵북로38길 21       / 한국우진학교 (중동)
# 3854              서울농학교     서울특별시 종로구 필운대로 103               (신교동)
# 3855              서울맹학교      서울특별시 종로구 필운대로 97               (신교동)
# 3856  경기기계공업고등학교부설공동실습소      서울특별시 노원구 공릉로 264    (하계동/경기기계공업고등학교)
#
# [3857 rows x 3 columns]

# %%
df_school.rename(columns={'도로명주소':'구명'}, inplace=True)
df_school.rename(columns={'도로명상세주소':'동명'}, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_school
# Out:
#                     학교명                     구명                  동명
# 0               선화예술중학교     서울특별시 광진구 천호대로 664    / 선화예술중고등학교 (능동)
# 1              서울숭신초등학교      서울특별시 성동구 마장로 161             (하왕십리동)
# 2                 행당중학교     서울특별시 성동구 왕십리로 189         (행당동/행당중학교)
# 3        한양대학교사범대학부속중학교       서울특별시 성동구 마조로 42  (사근동/한양사대부속중?고등학교)
# 4                 자양중학교    서울특별시 광진구 뚝섬로41길 33       (자양동/서울자양중학교)
# ...                 ...                    ...                 ...
# 3852           국립국악고등학교    서울특별시 강남구 개포로22길 65   / (개포동/ 국립국악고등학교)
# 3853             한국우진학교  서울특별시 마포구 월드컵북로38길 21       / 한국우진학교 (중동)
# 3854              서울농학교     서울특별시 종로구 필운대로 103               (신교동)
# 3855              서울맹학교      서울특별시 종로구 필운대로 97               (신교동)
# 3856  경기기계공업고등학교부설공동실습소      서울특별시 노원구 공릉로 264    (하계동/경기기계공업고등학교)
#
# [3857 rows x 3 columns]

# %%
df_gu = df_school['구명'].str.findall('\w+구')

# %%
df_gu
# Out:
# 0       [광진구]
# 1       [성동구]
# 2       [성동구]
# 3       [성동구]
# 4       [광진구]
#         ...
# 3852    [강남구]
# 3853    [마포구]
# 3854    [종로구]
# 3855    [종로구]
# 3856    [노원구]
# Name: 구명, Length: 3857, dtype: object

# %%
df_school['구명'] = df_gu
# Out:
# <ipython-input-11-586ea134eada>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_school['구명'] = df_gu

# %%
df_Dong = df_school['동명'].str.findall('\w+동')

# %%
df_Dong
# Out:
# 0          [능동]
# 1       [하왕십리동]
# 2         [행당동]
# 3         [사근동]
# 4         [자양동]
#          ...
# 3852      [개포동]
# 3853       [중동]
# 3854      [신교동]
# 3855      [신교동]
# 3856      [하계동]
# Name: 동명, Length: 3857, dtype: object

# %%
df_school['동명'] = df_Dong
# Out:
# <ipython-input-15-295ba2708356>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_school['동명'] = df_Dong

# %%
df_school
# Out:
#                     학교명     구명       동명
# 0               선화예술중학교  [광진구]     [능동]
# 1              서울숭신초등학교  [성동구]  [하왕십리동]
# 2                 행당중학교  [성동구]    [행당동]
# 3        한양대학교사범대학부속중학교  [성동구]    [사근동]
# 4                 자양중학교  [광진구]    [자양동]
# ...                 ...    ...      ...
# 3852           국립국악고등학교  [강남구]    [개포동]
# 3853             한국우진학교  [마포구]     [중동]
# 3854              서울농학교  [종로구]    [신교동]
# 3855              서울맹학교  [종로구]    [신교동]
# 3856  경기기계공업고등학교부설공동실습소  [노원구]    [하계동]
#
# [3857 rows x 3 columns]

# %%
df_element = df_school.loc[df_school['학교명'].str.contains("초등학교")]

# %%
df_element
# Out:
#                    학교명      구명       동명
# 1             서울숭신초등학교   [성동구]  [하왕십리동]
# 25              한양초등학교   [성동구]    [사근동]
# 26              세종초등학교   [광진구]    [군자동]
# 27              성동초등학교   [광진구]    [자양동]
# 28            서울화양초등학교   [광진구]    [화양동]
# ...                ...     ...      ...
# 1002         서울답십리초등학교  [동대문구]   [답십리동]
# 1003          서울군자초등학교  [동대문구]    [장안동]
# 1004            금성초등학교   [중랑구]    [신내동]
# 1005            경희초등학교  [동대문구]    [회기동]
# 1421  학력인정 한림초등학교(4년제)   [송파구]    [장지동]
#
# [611 rows x 3 columns]

# %%
df_element.rename(columns={'학교명':'초등학교명'}, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_element
# Out:
#                  초등학교명      구명       동명
# 1             서울숭신초등학교   [성동구]  [하왕십리동]
# 25              한양초등학교   [성동구]    [사근동]
# 26              세종초등학교   [광진구]    [군자동]
# 27              성동초등학교   [광진구]    [자양동]
# 28            서울화양초등학교   [광진구]    [화양동]
# ...                ...     ...      ...
# 1002         서울답십리초등학교  [동대문구]   [답십리동]
# 1003          서울군자초등학교  [동대문구]    [장안동]
# 1004            금성초등학교   [중랑구]    [신내동]
# 1005            경희초등학교  [동대문구]    [회기동]
# 1421  학력인정 한림초등학교(4년제)   [송파구]    [장지동]
#
# [611 rows x 3 columns]

# %%
df_element2 = df_element['구명']

# %%
type(df_element2[1])
# Out:
# list

# %%
# 인덱스 초기화
df3 =df_element.reset_index(level=None, drop=False)

# %%
df3
# Out:
#      index             초등학교명      구명       동명
# 0        1          서울숭신초등학교   [성동구]  [하왕십리동]
# 1       25            한양초등학교   [성동구]    [사근동]
# 2       26            세종초등학교   [광진구]    [군자동]
# 3       27            성동초등학교   [광진구]    [자양동]
# 4       28          서울화양초등학교   [광진구]    [화양동]
# ..     ...               ...     ...      ...
# 606   1002         서울답십리초등학교  [동대문구]   [답십리동]
# 607   1003          서울군자초등학교  [동대문구]    [장안동]
# 608   1004            금성초등학교   [중랑구]    [신내동]
# 609   1005            경희초등학교  [동대문구]    [회기동]
# 610   1421  학력인정 한림초등학교(4년제)   [송파구]    [장지동]
#
# [611 rows x 4 columns]

# %%
for col in df3:
    print(col)
# Out:
# index
# 초등학교명
# 구명
# 동명

# %%
df3.drop(['index'], axis=1, inplace=True)

# %%
# CSV 파일로 저장하기

# df3.to_csv('element.csv', mode='a', header=True, encoding='cp949')

#

# %%
df3
# Out:
#                 초등학교명      구명       동명
# 0            서울숭신초등학교   [성동구]  [하왕십리동]
# 1              한양초등학교   [성동구]    [사근동]
# 2              세종초등학교   [광진구]    [군자동]
# 3              성동초등학교   [광진구]    [자양동]
# 4            서울화양초등학교   [광진구]    [화양동]
# ..                ...     ...      ...
# 606         서울답십리초등학교  [동대문구]   [답십리동]
# 607          서울군자초등학교  [동대문구]    [장안동]
# 608            금성초등학교   [중랑구]    [신내동]
# 609            경희초등학교  [동대문구]    [회기동]
# 610  학력인정 한림초등학교(4년제)   [송파구]    [장지동]
#
# [611 rows x 3 columns]

# %%
print(df3)
# Out:
#                 초등학교명      구명       동명
# 0            서울숭신초등학교   [성동구]  [하왕십리동]
# 1              한양초등학교   [성동구]    [사근동]
# 2              세종초등학교   [광진구]    [군자동]
# 3              성동초등학교   [광진구]    [자양동]
# 4            서울화양초등학교   [광진구]    [화양동]
# ..                ...     ...      ...
# 606         서울답십리초등학교  [동대문구]   [답십리동]
# 607          서울군자초등학교  [동대문구]    [장안동]
# 608            금성초등학교   [중랑구]    [신내동]
# 609            경희초등학교  [동대문구]    [회기동]
# 610  학력인정 한림초등학교(4년제)   [송파구]    [장지동]
#
# [611 rows x 3 columns]

# %%
df4 = df3['구명']

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
# df4 = df3.groupby('구명').mean()

# %%
df4 = df3['구명']

# %%
df5 = df4

# %%
# df5[0] = '성동구'

# %%
# type(df5[0])
# Out:
# str

# %%
for a in df4:
    string=''.join(a)
    print(string)
# Out:
# 성동구
# 성동구
# 광진구
# 광진구
# 광진구
# 성동구
# 성동구
# 광진구
# 광진구
# 광진구
# 광진구
# 성동구
# 광진구
# 성동구
# 광진구
# 성동구
# 성동구
# 광진구
# 광진구
# 광진구
