# %%
# 데이터 가져오기

import pandas as pd

path = '../bicycle/bicycle.csv'

df = pd.read_csv(path, encoding = 'cp949')

df
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0
# 1     2019-11-04 8:56        3         중랑센터    2.0   7.0  1420.0
# 2     2019-11-04 8:57        3         중랑센터    7.0  10.0     NaN
# 3     2019-11-05 8:45        3         중랑센터    NaN  10.0  1380.0
# 4    2019-11-05 12:39        3         중랑센터    7.0  10.0  1650.0
# ..                ...      ...          ...    ...   ...     ...
# 415   2019-11-15 4:33      101  (구)합정동 주민센터    1.0  11.0  2200.0
# 416   2019-11-15 9:37      101  (구)합정동 주민센터    NaN   5.0     NaN
# 417  2019-11-15 20:53      101  (구)합정동 주민센터    1.0  12.0  2280.0
# 418  2019-11-15 22:05      101  (구)합정동 주민센터    1.0  10.0  1180.0
# 419  2019-11-15 23:04      101  (구)합정동 주민센터    5.0  48.0  8100.0
#
# [420 rows x 11 columns]

# %%
import numpy as np

df2 = df
df3 = df2.replace({'이용거리':np.nan}, {'이용거리':'무야호'})

# np.nan : 값을 직접 지정하고 싶을때 사용

# %%
df3
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0
# 1     2019-11-04 8:56        3         중랑센터    2.0   7.0  1420.0
# 2     2019-11-04 8:57        3         중랑센터    7.0  10.0     무야호
# 3     2019-11-05 8:45        3         중랑센터    NaN  10.0  1380.0
# 4    2019-11-05 12:39        3         중랑센터    7.0  10.0  1650.0
# ..                ...      ...          ...    ...   ...     ...
# 415   2019-11-15 4:33      101  (구)합정동 주민센터    1.0  11.0  2200.0
# 416   2019-11-15 9:37      101  (구)합정동 주민센터    NaN   5.0     무야호
# 417  2019-11-15 20:53      101  (구)합정동 주민센터    1.0  12.0  2280.0
# 418  2019-11-15 22:05      101  (구)합정동 주민센터    1.0  10.0  1180.0
# 419  2019-11-15 23:04      101  (구)합정동 주민센터    5.0  48.0  8100.0
#
# [420 rows x 11 columns]

# %%
mean646 = df2[df2['대여소번호']==646]['이용거리'].mean()

# %%
mean646
# Out:
# 1256.3157894736842

# %%
df2[df2['대여소번호']==646].replace({'이용거리':np.nan}, {'이용거리':mean646})
# Out:
#         자전거번호             대여일시  대여소번호               대여소명  대여거치대  \
# 0   SPB-23220  2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1   SPB-16216  2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2   SPB-21097  2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3   SPB-22292  2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 5   SPB-18401  2019-11-06 8:52    646  장한평역 1번출구 (국민은행앞)    1.0
# 6   SPB-18350  2019-11-06 8:35    646  장한평역 1번출구 (국민은행앞)    1.0
# 8   SPB-20220  2019-11-11 8:35    646  장한평역 1번출구 (국민은행앞)    2.0
# 9   SPB-20102  2019-11-11 9:45    646  장한평역 1번출구 (국민은행앞)    8.0
# 10  SPB-10000  2019-11-12 8:35    646  장한평역 1번출구 (국민은행앞)    8.0
# 11  SPB-20145  2019-11-13 8:30    646  장한평역 1번출구 (국민은행앞)    9.0
# 12  SPB-19057  2019-11-13 8:55    646  장한평역 1번출구 (국민은행앞)    4.0
# 13  SPB-19645  2019-11-14 9:44    646  장한평역 1번출구 (국민은행앞)    NaN
# 14  SPB-21851  2019-11-14 9:33    646  장한평역 1번출구 (국민은행앞)   10.0
# 15  SPB-13973  2019-11-15 8:42    646  장한평역 1번출구 (국민은행앞)    1.0
# 16  SPB-22311  2019-11-18 8:32    646  장한평역 1번출구 (국민은행앞)    6.0
# 17  SPB-02270  2019-11-18 8:49    646  장한평역 1번출구 (국민은행앞)    4.0
# 18  SPB-23659  2019-11-21 8:36    646  장한평역 1번출구 (국민은행앞)    NaN
# 19  SPB-23497  2019-11-21 8:50    646  장한평역 1번출구 (국민은행앞)    2.0
# 21  SPB-21810  2019-11-25 8:41    646  장한평역 1번출구 (국민은행앞)    5.0
# 22  SPB-05857  2019-11-26 8:40    646  장한평역 1번출구 (국민은행앞)    6.0
# 24  SPB-20076  2019-11-28 8:37    646  장한평역 1번출구 (국민은행앞)    6.0
#
#                 반납일시  반납대여소번호 반납대여소명  반납거치대  이용시간         이용거리
# 0    2019-11-01 9:01        3   중랑센터    7.0  12.0  1100.000000
# 1    2019-11-04 8:56        3   중랑센터    2.0   7.0  1420.000000
# 2    2019-11-04 8:57        3   중랑센터    7.0  10.0  1256.315789
# 3    2019-11-05 8:45        3   중랑센터    NaN  10.0  1380.000000
# 5    2019-11-06 9:09        3   중랑센터    7.0  11.0  1350.000000
# 6    2019-11-06 9:10        3   중랑센터    2.0   9.0  1390.000000
# 8    2019-11-11 8:42        3   중랑센터    2.0   6.0  1160.000000
# 9   2019-11-11 10:17        3   중랑센터    7.0  30.0  1060.000000
# 10   2019-11-12 8:44        3   중랑센터    2.0   8.0  1300.000000
# 11   2019-11-13 8:38        3   중랑센터    2.0   NaN  1060.000000
# 12   2019-11-13 9:08        3   중랑센터    7.0  11.0  1256.315789
# 13  2019-11-14 10:01        3   중랑센터    7.0  16.0  1140.000000
# 14  2019-11-14 10:02        3   중랑센터    2.0  28.0  1220.000000
# 15   2019-11-15 8:50        3   중랑센터    2.0   6.0  1370.000000
# 16   2019-11-18 8:39        3   중랑센터    2.0   NaN  1350.000000
# 17   2019-11-18 9:01        3   중랑센터    7.0  11.0  1350.000000
# 18   2019-11-21 8:44        3   중랑센터    2.0   6.0  1130.000000
# 19   2019-11-21 9:04        3   중랑센터    7.0  13.0  1330.000000
# 21   2019-11-25 8:49        3   중랑센터    2.0   7.0  1310.000000
# 22   2019-11-26 8:48        3   중랑센터    2.0   NaN  1380.000000
# 24   2019-11-28 8:44        3   중랑센터    2.0   5.0  1070.000000

# %%
df2[df2['이용거리']==646] = df2[df2['대여소번호']==646].replace({'이용거리':np.nan}, {'이용거리':mean646})

# %%
# 결측치 처리 순서

# 1. 결측열 찾기
# 2. 대여소 번호 얻기
# 3. 대여소 번호와 column 명을 전달하여 변경하기

# %%
def test(data_frame, rentNo):
    bool_rentNo = data_frame['대여번호']==rentNo
    print(type(bool_rentNo))
    print(bool_rentNo)
    mean_distance = data_frame[bool_rentNo]['이용거리'].mean()
    data_frame[bool_rentNo] = data_frame[bool_rentNo].replace({'이용거리':np.nan},{'이용거리':mean_distance})
    print(data_frame)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\5-17\jupylab\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '대여번호'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-da8a65254f9b> in <module>
#       7     print(data_frame)
#       8
# ----> 9 test(df,103)
#
# <ipython-input-21-da8a65254f9b> in test(data_frame, rentNo)
#       1 def test(data_frame, rentNo):
# ----> 2     bool_rentNo = data_frame['대여번호']==rentNo
#       3     print(type(bool_rentNo))
#       4     print(bool_rentNo)
#       5     mean_distance = data_frame[bool_rentNo]['이용거리'].mean()
#
# c:\users\5-17\jupylab\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\users\5-17\jupylab\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '대여번호'
