# %%
# 데이터 German credit data
# german credit.csv  Google(100구골)

import pandas as pd

url = "http://freakonometrics.free.fr/german_credit.csv"
pd.read_csv(url)                                   #url을 읽어오는 메소드
# Out:
#      Creditability  Account Balance  Duration of Credit (month)  \
# 0                1                1                          18
# 1                1                1                           9
# 2                1                2                          12
# 3                1                1                          12
# 4                1                1                          12
# ..             ...              ...                         ...
# 995              0                1                          24
# 996              0                1                          24
# 997              0                4                          21
# 998              0                2                          12
# 999              0                1                          30
#
#      Payment Status of Previous Credit  Purpose  Credit Amount  \
# 0                                    4        2           1049
# 1                                    4        0           2799
# ...
