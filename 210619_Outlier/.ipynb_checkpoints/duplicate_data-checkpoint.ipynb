# %%
# 결측치 (Missing Data)
# CSV 파일 읽어오기

import pandas as pd

path = "bicycle/bicycle_dup.csv"

dt = pd.read_csv(path, encoding='cp949')

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   자전거번호    420 non-null    object
#  1   대여일시     420 non-null    object
#  2   대여소번호    420 non-null    int64
#  3   대여소명     420 non-null    object
#  4   대여거치대    396 non-null    float64
#  5   반납일시     420 non-null    object
#  6   반납대여소번호  420 non-null    int64
#  7   반납대여소명   420 non-null    object
#  8   반납거치대    409 non-null    float64
#  9   이용시간     405 non-null    float64
#  10  이용거리     404 non-null    float64
#  11  나이       420 non-null    int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 39.5+ KB

# %%
dt.head(20)
# Out:
#         자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0   SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1   SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2   SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3   SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4   SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# 5   SPB-18401   2019-11-06 8:52    646  장한평역 1번출구 (국민은행앞)    1.0
# 6   SPB-18350   2019-11-06 8:35    646  장한평역 1번출구 (국민은행앞)    1.0
# 7   SPB-11557  2019-11-08 14:52      3               중랑센터    7.0
# 8   SPB-20220   2019-11-11 8:35    646  장한평역 1번출구 (국민은행앞)    2.0
# 9   SPB-20102   2019-11-11 9:45    646  장한평역 1번출구 (국민은행앞)    8.0
# 10  SPB-10000   2019-11-12 8:35    646  장한평역 1번출구 (국민은행앞)    8.0
# 11  SPB-20145   2019-11-13 8:30    646  장한평역 1번출구 (국민은행앞)    9.0
# 12  SPB-19057   2019-11-13 8:55    646  장한평역 1번출구 (국민은행앞)    4.0
# ...

# %%
dt[dt['이용시간'].isnull()]
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 11   SPB-20145   2019-11-13 8:30    646  장한평역 1번출구 (국민은행앞)    9.0
# 16   SPB-22311   2019-11-18 8:32    646  장한평역 1번출구 (국민은행앞)    6.0
# 22   SPB-05857   2019-11-26 8:40    646  장한평역 1번출구 (국민은행앞)    6.0
# 29   SPB-21611   2019-11-27 8:34    911    은평평화공원(역촌역4번출구)    NaN
# 44   SPB-14142  2019-11-01 13:06    152         마포구민체육센터 앞   27.0
# 57   SPB-07887  2019-11-01 20:22    104         합정역 1번출구 앞    6.0
# 76   SPB-07402  2019-11-02 16:45    151           망원1동주민센터    1.0
# 86   SPB-04854  2019-11-02 19:52    101        (구)합정동 주민센터    5.0
# 129  SPB-22403  2019-11-03 23:45    119            서강나루 공원   10.0
# 161  SPB-04641  2019-11-04 21:33    101        (구)합정동 주민센터    3.0
# 185  SPB-20864  2019-11-05 13:18    111         상수역 2번출구 앞   10.0
# 228  SPB-17074  2019-11-06 18:33    267          삼성화재 사옥 옆    2.0
# 311  SPB-18301  2019-11-09 23:40    103         망원역 2번출구 앞    9.0
# ...

# %%
dt[dt['이용거리']==2290]
# Out:
#          자전거번호              대여일시  대여소번호          대여소명  대여거치대  \
# 98   SPB-11651  2019-11-02 23:54    228   선유도역 3번출구 앞    8.0
# 400  SPB-15391  2019-11-14 17:14    113  홍대입구역 2번출구 앞   22.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리  나이
# 98    2019-11-03 0:09      101  (구)합정동 주민센터    3.0  15.0  2290.0  23
# 400  2019-11-14 17:29      101  (구)합정동 주민센터    1.0   NaN  2290.0  31

# %%
dt_group = dt.groupby('이용거리')
dt_group.mean()
# Out:
#                대여소번호     대여거치대  반납대여소번호     반납거치대   이용시간          나이
# 이용거리
# 0.0       130.583333  8.583333    101.0  2.272727   15.8   29.416667
# 20.0      101.000000  2.000000    101.0  3.000000    2.0   48.000000
# 280.0     260.000000  2.000000     53.0  3.500000    4.0  278.000000
# 440.0     106.000000  2.000000    101.0  1.000000   12.0   57.000000
# 450.0     262.500000  8.000000     53.0  4.000000   23.5   32.500000
# ...              ...       ...      ...       ...    ...         ...
# 10260.0  1160.000000  1.000000    101.0  1.000000   47.0   25.000000
# 12610.0  1925.000000  6.000000    101.0  4.000000   62.0   66.000000
# 16910.0  2103.000000  1.000000    101.0  1.000000  121.0   46.000000
# 17060.0  2103.000000  3.000000    101.0  4.000000  121.0   24.000000
# 42070.0   116.000000  3.000000    101.0  4.000000   46.0   22.000000
#
# [256 rows x 6 columns]

# %%
print(dt_group
